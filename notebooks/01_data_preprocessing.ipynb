# %% [markdown]
# # Arabic Text Summarization – Data Loading and Preprocessing

# %% [markdown]
# **Cell 1 — Imports**

# %%
import os
import re
import json
import glob
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Cell 2 — Set dataset path**

# %%
DATASET_DIR = Path("./dataset/raw_data")

print("Dataset folder exists:", DATASET_DIR.exists())
print("Dataset folder:", DATASET_DIR.resolve())
# Out:
# Dataset folder exists: True
# Dataset folder: C:\Users\moham\Desktop\NLP_Project\dataset\raw_data

# %% [markdown]
# **Cell 3 — List all files**

# %%
all_files = [p for p in DATASET_DIR.rglob("*") if p.is_file()]

print(f"Total files found: {len(all_files)}\n")
for f in all_files[:50]:
    print(f)
# Out:
# Total files found: 52
#
# dataset\raw_data\Arabic_Text_Summarisation\data.csv
# dataset\raw_data\Arabic_Text_Summarisation\summarizdataset.csv
# dataset\raw_data\AraSum\AbsArSumCorpus_DW_article tab lead.csv
# dataset\raw_data\AraSum\AraDPO.json
# dataset\raw_data\AraSum\AraRLHF.json
# dataset\raw_data\AraSum\README.md
# dataset\raw_data\Egyptian_Text_Summarisation\.gitattributes
# dataset\raw_data\Egyptian_Text_Summarisation\README.md
# dataset\raw_data\SumArabic\downloader.py
# dataset\raw_data\SumArabic\downloader_extractor.py
# dataset\raw_data\SumArabic\downloader_extractor_utils.py
# dataset\raw_data\SumArabic\sumarabic-1.0-index.jsonl.xz
# dataset\raw_data\SumArabic\sumarabic-1.0-ood.jsonl
# dataset\raw_data\SumArabic\sumarabic-1.0-test.jsonl
# dataset\raw_data\SumArabic\sumarabic-1.0-train.jsonl
# dataset\raw_data\SumArabic\sumarabic-1.0-valid.jsonl
# dataset\raw_data\SumArabic\__pycache__\downloader_extractor.cpython-313.pyc
# dataset\raw_data\SumArabic\__pycache__\downloader_extractor_utils.cpython-313.pyc
# dataset\raw_data\Egyptian_Text_Summarisation\.git\config
# dataset\raw_data\Egyptian_Text_Summarisation\.git\description
# dataset\raw_data\Egyptian_Text_Summarisation\.git\HEAD
# dataset\raw_data\Egyptian_Text_Summarisation\.git\index
# dataset\raw_data\Egyptian_Text_Summarisation\.git\packed-refs
# dataset\raw_data\Egyptian_Text_Summarisation\data\train-00000-of-00001.parquet
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\applypatch-msg.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\commit-msg.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\fsmonitor-watchman.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\post-checkout
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\post-commit
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\post-merge
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\post-update.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-applypatch.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-commit.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-merge-commit.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-push
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-push.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-rebase.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\pre-receive.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\prepare-commit-msg.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\push-to-checkout.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\sendemail-validate.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\hooks\update.sample
# dataset\raw_data\Egyptian_Text_Summarisation\.git\info\exclude
# dataset\raw_data\Egyptian_Text_Summarisation\.git\logs\HEAD
# dataset\raw_data\Egyptian_Text_Summarisation\.git\refs\heads\main
# dataset\raw_data\Egyptian_Text_Summarisation\.git\refs\remotes\origin\HEAD
# dataset\raw_data\Egyptian_Text_Summarisation\.git\objects\pack\pack-b706b4ebf6a7b310a4771d395d2154b70fb9ff65.idx
# dataset\raw_data\Egyptian_Text_Summarisation\.git\objects\pack\pack-b706b4ebf6a7b310a4771d395d2154b70fb9ff65.pack
# dataset\raw_data\Egyptian_Text_Summarisation\.git\objects\pack\pack-b706b4ebf6a7b310a4771d395d2154b70fb9ff65.rev
# dataset\raw_data\Egyptian_Text_Summarisation\.git\logs\refs\heads\main

# %% [markdown]
# **Cell 4 — Group files by extension**

# %%
from collections import Counter

ext_counts = Counter([f.suffix.lower() for f in all_files])
ext_counts
# Out:
# Counter({'': 17,
#          '.sample': 14,
#          '.jsonl': 4,
#          '.csv': 3,
#          '.py': 3,
#          '.json': 2,
#          '.md': 2,
#          '.pyc': 2,
#          '.xz': 1,
#          '.parquet': 1,
#          '.idx': 1,
#          '.pack': 1,
#          '.rev': 1})

# %% [markdown]
# **Cell 5 — Helper functions to load common file types**
#
# This makes it easier to load CSV, JSON, or JSONL.

# %%
def load_csv_file(path):
    return pd.read_csv(path)

def load_excel_file(path):
    return pd.read_excel(path)

def load_json_file(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return pd.DataFrame(data) if isinstance(data, list) else data

def load_jsonl_file(path):
    rows = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:
                rows.append(json.loads(line))
    return pd.DataFrame(rows)

def try_load_file(path):
    suffix = path.suffix.lower()
    try:
        if suffix == ".csv":
            return load_csv_file(path)
        elif suffix in [".xlsx", ".xls"]:
            return load_excel_file(path)
        elif suffix == ".json":
            return load_json_file(path)
        elif suffix == ".jsonl":
            return load_jsonl_file(path)
        elif suffix == ".parquet":
            return pd.read_parquet(path)
        else:
            return None
    except Exception as e:
        print(f"Could not load {path.name}: {e}")
        return None

# %% [markdown]
# **Cell 6 — Try loading likely dataset files**

# %%
candidate_files = [f for f in all_files if f.suffix.lower() in [".csv", ".json", ".jsonl", ".xlsx", ".xls", ".parquet"]]

print("Candidate data files:")
for i, f in enumerate(candidate_files):
    print(f"{i}: {f}")
# Out:
# Candidate data files:
# 0: dataset\raw_data\Arabic_Text_Summarisation\data.csv
# 1: dataset\raw_data\Arabic_Text_Summarisation\summarizdataset.csv
# 2: dataset\raw_data\AraSum\AbsArSumCorpus_DW_article tab lead.csv
# 3: dataset\raw_data\AraSum\AraDPO.json
# 4: dataset\raw_data\AraSum\AraRLHF.json
# 5: dataset\raw_data\SumArabic\sumarabic-1.0-ood.jsonl
# 6: dataset\raw_data\SumArabic\sumarabic-1.0-test.jsonl
# 7: dataset\raw_data\SumArabic\sumarabic-1.0-train.jsonl
# 8: dataset\raw_data\SumArabic\sumarabic-1.0-valid.jsonl
# 9: dataset\raw_data\Egyptian_Text_Summarisation\data\train-00000-of-00001.parquet

# %% [markdown]
# ## Load and process new file 0: `dataset\Arabic_Text_Summarisation\data.csv`

# %% [markdown]
# **Cell 7 — Load file by file**

# %%
file_index = 0 
selected_file = candidate_files[file_index]

print("Loading:", selected_file)

df = try_load_file(selected_file)

type(df)
# Out:
# Loading: dataset\raw_data\Arabic_Text_Summarisation\data.csv
# pandas.core.frame.DataFrame

# %% [markdown]
# **Cell 8 — Inspect the dataset**

# %%
if isinstance(df, pd.DataFrame):
    print("Shape:", df.shape)
    display(df.head())
    print("\nColumns:")
    print(df.columns.tolist())
else:
    print("Loaded object is not a DataFrame.")
    print(df)
# Out:
# Shape: (5227, 6)
#                                       Processed Text  \
# 0  اشرف رئيس الجمهوريه الباجي قايد السبسي اليوم ب...
# 1  تحصل كتاب المصحف وقراءاته الفه باحثون تونسيون ...
# 2  احتضن جناح تونس القريه الدوليه للافلام بمدينه ...
# 3  تنطلق فعاليات التظاهره الموسيقيه الالكترونيه ص...
# 4  ينطلق مهرجان القيروان للشعر العربي ببيت الشعر ...
#
#                                           summarizer  len-text  len-summarize  \
# 0  \nأشرف رئيس الجمهورية الباجي قايد السبسي اليوم...        80             28
# 1  \nتحصل كتاب "المصحف وقراءاته" الذي ألفه باحثون...        53             32
# 2  تونس حاضرة من جهة أخرى ستكون تونس حاضرة في قائ...       216             27
# 3  \nتنطلق فعاليات التظاهرة الموسيقية الالكترونية...        66             21
# 4  وستلتأم خلال اليوم الثاني الندوة النقدية بعنوا...       157             63
#
#    text - summarize done?
# 0                52   Yes
# 1                21   Yes
# 2               189   Yes
# 3                45   Yes
# 4                94   Yes
# Columns:
# ['Processed Text', 'summarizer', 'len-text', 'len-summarize', 'text - summarize', 'done?']

# %% [markdown]
# **Cell 9 — Check null values and duplicates**

# %%
if isinstance(df, pd.DataFrame):
    print("Null values per column:\n")
    print(df.isnull().sum())

    print("\nDuplicate rows:", df.duplicated().sum())
    if df.duplicated().sum()!=0:
        df=df.drop_duplicates()
# Out:
# Null values per column:
#
# Processed Text      0
# summarizer          0
# len-text            0
# len-summarize       0
# text - summarize    0
# done?               0
# dtype: int64
#
# Duplicate rows: 197

# %% [markdown]
# **Cell 10 — Identify the article and summary columns**

# %%
ARTICLE_COL = "Processed Text"  
SUMMARY_COL = "summarizer"  

print("Article column:", ARTICLE_COL)
print("Summary column:", SUMMARY_COL)
# Out:
# Article column: Processed Text
# Summary column: summarizer

# %% [markdown]
# **Cell 11 — Keep only the important columns**

# %%
df = df[[ARTICLE_COL, SUMMARY_COL]].copy()
df = df.dropna(subset=[ARTICLE_COL, SUMMARY_COL]).drop_duplicates()

print("Cleaned shape:", df.shape)
display(df.head())
# Out:
# Cleaned shape: (5030, 2)
#                                       Processed Text  \
# 0  اشرف رئيس الجمهوريه الباجي قايد السبسي اليوم ب...
# 1  تحصل كتاب المصحف وقراءاته الفه باحثون تونسيون ...
# 2  احتضن جناح تونس القريه الدوليه للافلام بمدينه ...
# 3  تنطلق فعاليات التظاهره الموسيقيه الالكترونيه ص...
# 4  ينطلق مهرجان القيروان للشعر العربي ببيت الشعر ...
#
#                                           summarizer
# 0  \nأشرف رئيس الجمهورية الباجي قايد السبسي اليوم...
# 1  \nتحصل كتاب "المصحف وقراءاته" الذي ألفه باحثون...
# 2  تونس حاضرة من جهة أخرى ستكون تونس حاضرة في قائ...
# 3  \nتنطلق فعاليات التظاهرة الموسيقية الالكترونية...
# 4  وستلتأم خلال اليوم الثاني الندوة النقدية بعنوا...

# %% [markdown]
# **Cell 12 — Print raw Arabic examples**

# %%
for i in range(min(5, len(df))):
    print("=" * 80)
    print(f"Example {i+1}")
    print("\nARTICLE:\n")
    print(df.iloc[i][ARTICLE_COL])
    print("\nSUMMARY:\n")
    print(df.iloc[i][SUMMARY_COL])
    print()
# Out:
# ================================================================================
# Example 1
#
# ARTICLE:
#
# اشرف رئيس الجمهوريه الباجي قايد السبسي اليو
abic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ      # Tatwil/Kashida
                         """, re.VERBOSE)

def remove_diacritics(text):
    text = str(text)
    return re.sub(arabic_diacritics, "", text)


def normalize_arabic(text):
    text = str(text)

    # Normalize different forms of Alef
    text = re.sub(r"[إأآا]", "ا", text)
    # text = re.sub(r"ى", "ي", text)
    # text = re.sub(r"ئ", "ي", text)
    # text = re.sub(r"ؤ", "و", text)
    text = re.sub(r"ة", "ه", text)
    text = re.sub(r"گ", "ك", text)

    return text


def clean_arabic_text(text):
    text = str(text)

    # Remove URLs
    text = re.sub(r"http\S+|www\S+|https\S+", " ", text)

    # Remove email addresses
    text = re.sub(r"\S+@\S+", " ", text)

    # Remove diacritics
    text = remove_diacritics(text)

    # Normalize Arabic letters
    text = normalize_arabic(text)

    # Separate concatenated و from Arabic words
    # Example: والاقتصاد -> و الاقتصاد
    text = re.sub(r"\bو(?=[\u0621-\u064A]{2,})", "و ", text)

    # Remove punctuation marks whether loose or concatenated
    punctuation_pattern = r"[!:\'’،؛\"/؟,.،؛()\[\]{}<>ـ\-–—]"
    text = re.sub(punctuation_pattern, " ", text)

    # Keep Arabic letters and spaces only
    text = re.sub(r"[^\u0600-\u06FF\s]", " ", text)

    # Remove single Arabic letters surrounded by spaces
    # Example: "ذهب ا الى" -> "ذهب الى"
    text = re.sub(r"(?<=\s)[\u0621-\u064A](?=\s)", " ", text)

    # Remove single Arabic letter at beginning or end
    text = re.sub(r"^[\u0621-\u064A]\s+", " ", text)
    text = re.sub(r"\s+[\u0621-\u064A]$", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# **Cell 14 — Test preprocessing on a few rows**

# %%
sample_df = df.head(5).copy()

sample_df["clean_article"] = sample_df[ARTICLE_COL].apply(clean_arabic_text)
sample_df["clean_summary"] = sample_df[SUMMARY_COL].apply(clean_arabic_text)

for i in range(len(sample_df)):
    print("=" * 100)
    print(f"Sample {i+1}")
    
    print("\nORIGINAL ARTICLE:\n")
    print(sample_df.iloc[i][ARTICLE_COL])
    
    print("\nCLEAN ARTICLE:\n")
    print(sample_df.iloc[i]["clean_article"])
    
    print("\nORIGINAL SUMMARY:\n")
    print(sample_df.iloc[i][SUMMARY_COL])
    
    print("\nCLEAN SUMMARY:\n")
    print(sample_df.iloc[i]["clean_summary"])
# Out:
# ====================================================================================================
# Sample 1
#
# ORIGINAL ARTICLE:
#
# اشرف رئيس الجمهوريه الباجي قايد السبسي اليوم بقصر قرطاج موكب منح الوسام الوطني للاستحقاق الثقافي الفنانين والمبدعين بمناسبه انعقاد ايام قرطاج السينمائيه والفنانون الصنف عبد الرحمان سيساكو موريتانيا جميل راتب مصر ميشال خليفي فلسطين ادريسا ودراغو بوركينا فاسو محمد ملص سوريا رضا الباهي تونس الحضور عمر الخليفي تونس الصنف الثاني عبد العزيز بن ملوكه تونس نجيب تونس منصف شرف الدين تونس الحضور الصنف الثالث ابراهيم تونس الخياطي تونس الحضور تونس عليها الحضور شوقي الماجري تونس الصنف الرابع كوثر بن تونس
#
# CLEAN ARTICLE:
#
# اشرف رئيس الجمهوريه الباجي قايد السبسي اليو
شرف رئيس الجمهوريه الباجي قايد السبسي اليوم ب...
# 1  تحصل كتاب المصحف وقراءاته الفه باحثون تونسيون ...
# 2  احتضن جناح تونس القريه الدوليه للافلام بمدينه ...
# 3  تنطلق فعاليات التظاهره الموسيقيه الالكترونيه ص...
# 4  ينطلق مهرجان القيروان للشعر العربي ببيت الشعر ...
#
#                                           summarizer  \
# 0  \nأشرف رئيس الجمهورية الباجي قايد السبسي اليوم...
# 1  \nتحصل كتاب "المصحف وقراءاته" الذي ألفه باحثون...
# 2  تونس حاضرة من جهة أخرى ستكون تونس حاضرة في قائ...
# 3  \nتنطلق فعاليات التظاهرة الموسيقية الالكترونية...
# 4  وستلتأم خلال اليوم الثاني الندوة النقدية بعنوا...
#
#                                        clean_article  \
# 0  اشرف رئيس الجمهوريه الباجي قايد السبسي اليوم ب...
# 1  تحصل كتاب المصحف قراءاته الفه باحثون تونسيون م...
# 2  احتضن جناح تونس القريه الدوليه للافلام بمدينه ...
# 3  تنطلق فعاليات التظاهره الموسيقيه الالكترونيه ص...
# 4  ينطلق مهرجان القيروان للشعر العربي ببيت الشعر ...
#
#                                        clean_summary
# 0  اشرف رئيس الجمهوريه الباجي قايد السبسي اليوم ب...
# 1  تحصل كتاب المصحف قراءاته الذي الفه باحثون تونس...
# 2  تونس حاضره من جهه اخرى ستكون تونس حاضره في قائ...
# 3  تنطلق فعاليات التظاهره الموسيقيه الالكترونيه ص...
# 4  ستلتام خلال اليوم الثاني الندوه النقديه بعنوان...

# %% [markdown]
# **Cell 16 — Simple tokenization**

# %%
def simple_tokenize(text):
    return str(text).split()

df["article_tokens"] = df["clean_article"].apply(simple_tokenize)
df["summary_tokens"] = df["clean_summary"].apply(simple_tokenize)

# %% [markdown]
# **Cell 17 — Length statistics**

# %%
df["article_len"] = df["article_tokens"].apply(len)
df["summary_len"] = df["summary_tokens"].apply(len)

print("Article length stats:")
print(df["article_len"].describe())

print("\nSummary length stats:")
print(df["summary_len"].describe())
# Out:
# Article length stats:
# count    5030.000000
# mean       84.063022
# std        49.153820
# min        23.000000
# 25%        52.000000
# 50%        70.000000
# 75%        98.000000
# max       461.000000
# Name: article_len, dtype: float64
#
# Summary length stats:
# count    5030.000000
# mean       30.269781
# std        12.991890
# min         0.000000
# 25%        20.000000
# 50%        27.000000
# 75%        42.000000
# max        62.000000
# Name: summary_len, dtype: float64

# %% [markdown]
# **Cell 18 — Plot token length distributions**

# %%
plt.figure(figsize=(10, 5))
plt.hist(df["article_len"], bins=50)
plt.title("Article Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 5))
plt.hist(df["summary_len"], bins=50)
plt.title("Summary Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Cell 19 — Filter empty or extremely short rows**

# %%
df = df[
    (df["clean_article"].str.strip() != "") &
    (df["clean_summary"].str.strip() != "") &
    (df["article_len"] >= 5) &
    (df["summary_len"] >= 3)
].copy()

print("Shape after filtering:", df.shape)
# Out:
# Shape after filtering: (5010, 8)

# %% [markdown]
# **Cell 20 — Save a cleaned version**

# %%
OUTPUT_DIR = Path("./dataset/processed_data")
OUTPUT_DIR.mkdir(exist_ok=True)

folder_name = selected_file.parent.name
file_name = selected_file.stem  
output_path = OUTPUT_DIR / f"cleaned_{folder_name}_{file_name}.csv"

df.to_csv(output_path, index=False, encoding="utf-8-sig")

print("Saved cleaned dataset to:", output_path.resolve())
# Out:
# Saved cleaned dataset to: C:\Users\moham\Desktop\NLP_Project\dataset\processed_data\cleaned_Arabic_Text_Summarisation_data.csv

# %% [markdown]
# ## Load and process file 2: `dataset\AraSum\AbsArSumCorpus_DW_article tab lead.csv`

# %% [markdown]
# **Cell 7 — Load file by file**

# %%
file_index = 2
selected_file = candidate_files[file_index]

print("Loading:", selected_file)

df = pd.read_csv(selected_file, sep="\t", encoding="utf-8")

safe_file_name = re.sub(r"\s+", "_", selected_file.stem)
print("Safe filename:", safe_file_name)

print(type(df))
print(df.shape)
display(df.head())
# Out:
# Loading: dataset\raw_data\AraSum\AbsArSumCorpus_DW_article tab lead.csv
# Safe filename: AbsArSumCorpus_DW_article_tab_lead
# <class 'pandas.core.frame.DataFrame'>
# (49603, 3)
#    0  \
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#
#   حقق حزب "البديل من أجل ألمانيا" اليميني الشعبوي أفضل نتائجه في أحدث استطلاعات الرأي بحصوله على تأييد 16% من الألمان في جميع أنحاء ألمانيا. وأظهر الاستطلاع الذي أجراه معهد "إنفراتست ديماب" بتكليف من شبكة (ARD)إيه آر دي الإعلامية الألمانية أن شعبية الحزب ارتفعت بذلك بنسبة 2% مقارنة باستطلاع مماثل أجري مطلع الشهر الجاري لشبكة(ZDF) تسي دي إف الإخبارية. وحصل التحالف المسيحي، المنتمية إليه المستشارة أنغيلا ميركل، في الاستطلاع الذي نشرت نتائجه اليوم الجمعة (23أيلول/ سبتمبر 2016 )على نسبة 32% بتراجع قدره 1% عن الاستطلاع السابق. كما تراجعت شعبية الحزب الاشتراكي الديمقراطي، الشريك في الائتلاف الحاكم، بنفس النسبة ليحصل على نسبة 22%. وفي المقابل، ارتفعت شعبية حزب الخضر بمقدار 1% لتصل إلى 12%، بينما تراجعت شعبية حزب "اليسار" بنسبة 1% ليحصل على نسبة 8%، في حين ارتفعت شعبية الحزب الديمقراطي الحر بنسبة 1% إلى 6%. وعن نتائج استطلاعات الرأي، قال وزير شؤون ديوان المستشارية بيتر ألتماير في تصريحات لـ"إيه آر دي" إن استطلاعات الرأي لم تعد تبعث على التفاؤل بالنسبة لأي حزب من الأحزاب الممثلة في البرلمان الألماني (بوندستاغ). وأضاف ألتماير المنتمي إلى الحزب المسيحي الديمقراطي الذي تتزعمه المستشارة ميركل: "هذا الأمر له علاقة بأننا نحل مشكلات صعبة في هذا البلد... لكننا متأكدون من أن نتائج الاستطلاعات ستتحسن عندما يتمكن المواطنون من رؤية واستشعار سيطرتنا على هذه المشكلات". وشارك حوالي 934 ألمانيا فوق 18 عاما في الاستطلاع الذي أجري خلال الفترة من 19 حتى 21 أيلول/سبتمبر الجاري. ع.أ.ج/ ح ح (د ب أ)  \
# 0  بدأت اليوم الجمعة( 23 أيلول/ سبتمبر 2016 ) في ...
# 1  قال مسؤولون إن شخصا أصيب إصابة بالغة بعد تعرضه...
# 2  أعلن مسؤول في البنتاغون أن جنودا أمريكيين في ش...
# 3  اجتمعت المجموعة الدولية لدعم سوريا على هامش اج...
# 4  قال الإيطالي كارلو أنشيلوتي المدير الفني لفريق...
#
#   تشير آخر استطلاعات الرأي الألمانية إلى تقدم حزب البديل اليميني في حين يستمر تراجع الحزب المسيحي الديمقراطي الذي تقوده المستشارة ميركل. وصرحت مصادر رسمية أن النتائج باتت غير مشجعة للأحزاب الموجودة في البرلمان الألماني.
# 0  بدأت محكمة ميونخ النظر في اتهامات متعلقة برجل ...
# 1  أعلن حاكم كارولاينا الشمالية حالة الطورائ في م...
# 2  قالت وزارة الدفاع الأمريكية (البنتاغون) إن داع...
# 3  فشلت الولايات المتحدة وروسيا في الاتفاق على كي...
# 4  أثنى مدرب بايرن ميونيخ كارلو أنشيلوتي على مساع...

# %% [markdown]
# **Cell 8 — Inspect the dataset**

# %%
if isinstance(df, pd.DataFrame):
    print("Shape:", df.shape)

    print("\nOriginal columns:")
    print(df.columns.tolist())

    # Reset columns to numeric first
    df.columns = range(df.shape[1])

    # Keep only the first 3 columns
    df = df.iloc[:, :3].copy()

    # Rename them correctly
    df.columns = ["index", "article", "summary"]

    # Reset numbering if needed
    df = df.reset_index(drop=True)

    print("\nFinal columns:", df.columns.tolist())
    display(df.head())

else:
    print("Loaded object is not a DataFrame.")
    print(df)
# Out:
# Shape: (49603, 3)
#
# Original columns:
# ['0', 'حقق حزب "البديل من أجل ألمانيا" اليميني الشعبوي أفضل نتائجه في أحدث استطلاعات الرأي بحصوله على تأييد 16% من الألمان في جميع أنحاء ألمانيا. وأظهر الاستطلاع الذي أجراه معهد "إنفراتست ديماب" بتكليف من شبكة (ARD)إيه آر دي الإعلامية الألمانية أن شعبية الحزب ارتفعت بذلك بنسبة 2% مقارنة باستطلاع مماثل أجري مطلع الشهر الجاري لشبكة(ZDF) تسي دي إف الإخبارية. وحصل التحالف المسيحي، المنتمية إليه المستشارة أنغيلا ميركل، في الاستطلاع الذي نشرت نتائجه اليوم الجمعة (23أيلول/ سبتمبر 2016 )على نسبة 32% بتراجع قدره 1% عن الاستطلاع السابق. كما تراجعت شعبية الحزب الاشتراكي الديمقراطي، الشريك في الائتلاف الحاكم، بنفس النسبة ليحصل على نسبة 22%. وفي المقابل، ارتفعت شعبية حزب الخضر بمقدار 1% لتصل إلى 12%، بينما تراجعت شعبية حزب "اليسار" بنسبة 1% ليحصل على نسبة 8%، في حين ارتفعت شعبية الحزب الديمقراطي الحر بنسبة 1% إلى 6%. وعن نتائج استطلاعات الرأي، قال وزير شؤون ديوان المستشارية بيتر ألتماير في تصريحات لـ"إيه آر دي" إن استطلاعات الرأي لم تعد تبعث على التفاؤل بالنسبة لأي حزب من الأحزاب الممثلة في البرلمان الألماني (بوندستاغ). وأضاف ألتماير المنتمي إلى الحزب المسيحي الديمقراطي الذي تتزعمه المستشارة ميركل: "هذا الأمر له علاقة بأننا نحل مشكلات صعبة في هذا البلد... لكننا متأكدون من أن نتائج الاستطلاعات ستتحسن عندما يتمكن المواطنون من رؤية واستشعار سيطرتنا على هذه المشكلات". وشارك حوالي 934 ألمانيا فوق 18 عاما في الاستطلاع الذي أجري خلال الفترة من 19 حتى 21 أيلول/سبتمبر الجاري. ع.أ.ج/ ح ح (د ب أ)', 'تشير آخر استطلاعات الرأي الألمانية إلى تقدم حزب البديل اليميني في حين يستمر تراجع الحزب المسيحي الديمقراطي الذي تقوده المستشارة ميركل. وصرحت مصادر رسمية أن النتائج باتت غير مشجعة للأحزاب الموجودة في البرلمان الألماني.']
#
# Final columns: ['index', 'article', 'summary']
#    index                                            article  \
# 0      1  بدأت اليوم الجمعة( 23 أيلول/ سبتمبر 2016 ) في ...
# 1      2  قال مسؤولون إن شخصا أصيب إصابة بالغة بعد تعرضه...
# 2      3  أعلن مسؤول في البنتاغون أن جنودا أمريكيين في ش...
# 3      4  اجتمعت المجموعة الدولية لدعم سوريا على هامش اج...
# 4      5  قال الإيطالي كارلو أنشيلوتي المدير الفني لفريق...
#
#                                              summary
# 0  بدأت محكمة ميونخ النظر في اتهامات متعلقة برجل ...
# 1  أعلن حاكم كارولاينا الشمالية حالة الطورائ في م...
# 2  قالت وزارة الدفاع الأمريكية (البنتاغون) إن داع...
# 3  فشلت الولايات المتحدة وروسيا في الاتفاق على كي...
# 4  أثنى مدرب بايرن ميونيخ كارلو أنشيلوتي على مساع...

# %% [markdown]
# **Cell 9 — Check null values and duplicates**

# %%
if isinstance(df, pd.DataFrame):
    print("Null values per column:\n")
    print(df.isnull().sum())

    print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Null values per column:
#
# index      0
# article    0
# summary    0
# dtype: int64
#
# Duplicate rows: 0

# %% [markdown]
# **Cell 10 — Identify the article and summary columns**

# %%
ARTICLE_COL = "article"  
SUMMARY_COL = "summary"  

print("Article column:", ARTICLE_COL)
print("Summary column:", SUMMARY_COL)
# Out:
# Article column: article
# Summary column: summary

# %% [markdown]
# **Cell 11 — Keep only the important columns**

# %%
df = df[[ARTICLE_COL, SUMMARY_COL]].copy()
df = df.dropna(subset=[ARTICLE_COL, SUMMARY_COL]).drop_duplicates()

print("Cleaned shape:", df.shape)
display(df.head())
# Out:
# Cleaned shape: (49581, 2)
#                                              article  \
# 0  بدأت اليوم الجمعة( 23 أيلول/ سبتمبر 2016 ) في ...
# 1  قال مسؤولون إن شخصا أصيب إصابة بالغة بعد تعرضه...
# 2  أعلن مسؤول في البنتاغون أن جنودا أمريكيين في ش...
# 3  اجتمعت المجموعة الدولية لدعم سوريا على هامش اج...
# 4  قال الإيطالي كارلو أنشيلوتي المدير الفني لفريق...
#
#                                              summary
# 0  بدأت محكمة ميونخ النظر في اتهامات متعلقة برجل ...
# 1  أعلن حاكم كارولاينا الشمالية حالة الطورائ في م...
# 2  قالت وزارة الدفاع الأمريكية (البنتاغون) إن داع...
# 3  فشلت الولايات المتحدة وروسيا في الاتفاق على كي...
# 4  أثنى مدرب بايرن ميونيخ كارلو أنشيلوتي على مساع...

# %% [markdown]
# **Cell 12 — Print raw Arabic examples**

# %%
for i in range(min(5, len(df))):
    print("=" * 80)
    print(f"Example {i+1}")
    print("\nARTICLE:\n")
    print(df.iloc[i][ARTICLE_COL])
    print("\nSUMMARY:\n")
    print(df.iloc[i][SUMMARY_COL])
    print()
# Out:
# ================================================================================
# Example 1
#
# ARTICLE:
#
# بدأت اليوم الجمعة( 23 أيلول/ سبتمبر 2016 ) في ميونيخ محاكمة رجل من جمهورية الجبل الأسود ( مونتينيغرو)، اعتقل في ألمانيا للاشتباه في انه كان ينقل أسلحة قبل أيام من اعتداءات باريس التي حصلت في تشرين الثاني/نوفمبر العام الماضي. وتريد المحكمة معرفة عما إذا كانت هذه الأسلحة أعدت للاستخدام في هجمات فرنسا. وقالت المتحدثة إن المتهم "اعترف أنه كان على علم بوجود أسلحة في سيارته، لكنه لا يعرف ما إذا كانت ستستخدم لتنفيذ اعتداء". وأضافت المتحدثة أن الرجل الذي يبلغ الحادية والخمسين ويدعى فوسيليتش، ملاحق "بتهمة التآمر في الإعداد لأعمال عنف يهدد امن الدولة" الفرنسية. واعتقل الرجل في 5 تشرين الثاني/نوفمبر 2015 على طريق سريع في ولاية بافاريا، على مقربة من الحدود النمساوية. حيث عثر رجال الشرطة في سيارته على كمية من الأسلحة و عدد كبير من القنابل اليدوية وبنادق كالاشنيكوف ومسدسات ومتفجرات. و أدخل فوسيليتش في جهاز "جي.بي.اس" خاص به عنوانا في باريس، وقد عثر على هذا العنوان مكتوبا على قصاصة ورق أيضا،و كتب على الورقة رقم هاتف فرنسي عائد على الأرجح لمتعاون مع المتهم، لكن لم يتم التعرف إليه بعد. وجاء في قرار الاتهام أن المتهم كان يريد أن يسلم المتعاون هذه الأسلحة لدى وصوله إلى باريس. وفي المقابل، كان سيحصل على ألفي يورو لقاء القيام بهذه المهمة. وتعذر رسميا إيجاد أي صلة بينه وبين اعتداءات باريس التي وقعت بعد أيام، وأضافت النيابة العامة في ميونيخ في قرار الاتهام إن "المتهم كان يعرف أن هناك هجمات استهدفت في كانون الثاني/يناير 2015 في باريس" مجلة شارلي إيبدو الأسبوعية التي قتل خلالها 12 شخصا. وتابعت ومع ذلك "كان ينقل عن سابق تصور وتصميم إلى باريس (أسلحة) تستخدم في هجمات انتحارية". ومن المقرر أن تنتهي المحاكمة في 30 أيلول/سبتمبر. يذكر انه في 13 تشرين الثاني/نوفمبر 2015 شن تنظيم "الدولة الإسلامية" المعروف إعلاميا بـ داعش ، اعتداءات على قاعة الحفلات بمسرح باتاكلان وأمام عدد من المقاهي في العاصمة وكذلك قرب ستاد دو فرانس، حيث أسفرت هذه الاعتداءات عن 130 قتيلا وأكثر من 350 جريحا. ع.أ.ج/ ع ج (أ ف ب)
#
# SUMMARY:
#
# بدأت محكمة ميونخ النظر في اتهامات متعلقة برجل من جمهورية الجبل الأسود حاول نقل أسلحة إلى فرنسا، وقبضت الشرطة الألمانية على الرجل بالقرب من الحدود النمساوية، حيث أعترف بعلمه بنقل الأسلحة إلا أنه لم يكن يعرف السبب.
يبا للآمال." وأضاف "في الوقت نفسه ..يستأنف الجميع الصراع. ستكون الساعات والأيام القليلة القادمة على الأكثر حاسمة فيما يتعلق بالنجاح أو الفشل." فيما قال وزير الخارجية الألمانية فرانك فالتر شتاينماير "لم ننجح حتى الآن ولكن كان هناك الكثير من الدعم حول الطاولة للمقترح المتمثل في حظر مؤقت لتحليق جميع الطائرات من أجل تهيئة الظروف للهدنة." وطالب كيري يوم الأربعاء بأن توقف روسيا والحكومة السورية على الفور تحليق الطائرات فوق مناطق الصراع بسوريا. من جانبه، قال وزير الخارجية الروسية سيرغي لافروف إنه يتعين على المعارضة السورية اتخاذ خطوات نحو التوصل إلى تسوية. م.م ع.ج (رويترز)
#
# SUMMARY:
#
# فشلت الولايات المتحدة وروسيا في الاتفاق على كيفية استئناف وقف إطلاق النار في سوريا خلال اجتماع وصفه وسيط الأمم المتحدة إلى سوريا بأنه كان "مطولا وشاقا ومخيبا للآمال".
#
# ================================================================================
# Example 5
#
# ARTICLE:
#
# قال الإيطالي كارلو أنشيلوتي المدير الفني لفريق بايرن ميونيخ الألماني لكرة القدم، إن مساعده السابق زين الدين زيدان، المدير الفني لريال مدريد الأسباني، حقق انطلاقة قوية في تدريب الملكي من خلال علاقته المتميزة مع اللاعبين. وكان ريال مدريد على بعد خطوة من الانفراد بالرقم القياسي لأكبر عدد من الانتصارات المتتالية في الدوري الأسباني، لكن الفريق تعادل مع فياريال 1 / 1 أمس الأول الأربعاء، إلا أن إهدار الفرصة لم يخف الانطلاقة القوية للفريق تحت قيادة النجم الفرنسي السابق. وكان زيدان، الفائز بلقب أفضل لاعب في العالم، قد عمل مدربا مساعدا لأنشيلوتي في ريال مدريد خلال موسم 2013 / 2014 . وقال أنشيلوتي إنه منذ ذلك الحين، كان واضحا مدى احترام وتقدير اللاعبين لزيدان وكذلك مدى قدرته على الاستفادة من تعاون نجوم الفريق معه من خلال علاقته المتميزة بهم. وقال أنشيلوتي في تصريحات لصحيفة "ليكيب" الفرنسية "زيدان يتمتع بحضور هائل واحترام كبير لدى اللاعبين. رأيت ذلك منذ أن كان مساعدا لي وأعتقد أن هذا هو مفتاح نجاحه." وأضاف "كانت هناك مشكلات لدى اللاعبين إزاء (المدرب السابق للفريق رافاييل) بينيتيز وبعدها تغير كل شيء مع قدوم زيدان. اللاعبون يدعمونه تماما." ع.ج/ م./ (د ب أ)
#
# SUMMARY:
#
# أثنى مدرب بايرن ميونيخ كارلو أنشيلوتي على مساعده السابق زين الدين زيدان مدرب ريال المدريد وانطلاقته القوية هذا الموسم، معيدا ذلك إلى العلاقة المميزة بين زيدان ولاعب الفريق الملكي.

# %% [markdown]
# **Cell 13 — Arabic preprocessing functions**

# %%
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ      # Tatwil/Kashida
                         """, re.VERBOSE)

def remove_diacritics(text):
    text = str(text)
    return re.sub(arabic_diacritics, "", text)


def normalize_arabic(text):
    text = str(text)

    # Normalize different forms of Alef
    text = re.sub(r"[إأآا]", "ا", text)
    # text = re.sub(r"ى", "ي", text)
    # text = re.sub(r"ئ", "ي", text)
    # text = re.sub(r"ؤ", "و", text)
    text = re.sub(r"ة", "ه", text)
    text = re.sub(r"گ", "ك", text)

    return text


def clean_arabic_text(text):
    text = str(text)

    # Remove URLs
    text = re.sub(r"http\S+|www\S+|https\S+", " ", text)

    # Remove email addresses
    text = re.sub(r"\S+@\S+", " ", text)

    # Remove diacritics
    text = remove_diacritics(text)

    # Normalize Arabic letters
    text = normalize_arabic(text)

    # Separate concatenated و from Arabic words
    # Example: والاقتصاد -> و الاقتصاد
    text = re.sub(r"\bو(?=[\u0621-\u064A]{2,})", "و ", text)

    # Remove punctuation marks whether loose or concatenated
    punctuation_pattern = r"[!:\'’،؛\"/؟,.،؛()\[\]{}<>ـ\-–—]"
    text = re.sub(punctuation_pattern, " ", text)

    # Keep Arabic letters and spaces only
    text = re.sub(r"[^\u0600-\u06FF\s]", " ", text)

    # Remove single Arabic letters surrounded by spaces
    # Example: "ذهب ا الى" -> "ذهب الى"
    text = re.sub(r"(?<=\s)[\u0621-\u064A](?=\s)", " ", text)

    # Remove single Arabic letter at beginning or end
    text = re.sub(r"^[\u0621-\u064A]\s+", " ", text)
    text = re.sub(r"\s+[\u0621-\u064A]$", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# **Cell 14 — Test preprocessing on a few rows**

# %%
sample_df = df.head(5).copy()

sample_df["clean_article"] = sample_df[ARTICLE_COL].apply(clean_arabic_text)
sample_df["clean_summary"] = sample_df[SUMMARY_COL].apply(clean_arabic_text)

for i in range(len(sample_df)):
    print("=" * 100)
    print(f"Sample {i+1}")
    
    print("\nORIGINAL ARTICLE:\n")
    print(sample_df.iloc[i][ARTICLE_COL])
    
    print("\nCLEAN ARTICLE:\n")
    print(sample_df.iloc[i]["clean_article"])
    
    print("\nORIGINAL SUMMARY:\n")
    print(sample_df.iloc[i][SUMMARY_COL])
    
    print("\nCLEAN SUMMARY:\n")
    print(sample_df.iloc[i]["clean_summary"])
# Out:
# ====================================================================================================
# Sample 1
#
# ORIGINAL ARTICLE:
#
# بدأت اليوم الجمعة( 23 أيلول/ سبتمبر 2016 ) في ميونيخ محاكمة رجل من جمهورية الجبل الأسود ( مونتينيغرو)، اعتقل في ألمانيا للاشتباه في انه كان ينقل أسلحة قبل أيام من اعتداءات باريس التي حصلت في تشرين الثاني/نوفمبر العام الماضي. وتريد المحكمة معرفة عما إذا كانت هذه الأسلحة أعدت للاستخدام في هجمات فرنسا. وقالت المتحدثة إن المتهم "اعترف أنه كان على علم بوجود أسلحة في سيارته، لكنه لا يعرف ما إذا كانت ستستخدم لتنفيذ اعتداء". وأضافت المتحدثة أن الرجل الذي يبلغ الحادية والخمسين ويدعى فوسيليتش، ملاحق "بتهمة التآمر في الإعداد لأعمال عنف يهدد امن الدولة" الفرنسية. واعتقل الرجل في 5 تشرين الثاني/نوفمبر 2015 على طريق سريع في ولاية بافاريا، على مقربة من الحدود النمساوية. حيث عثر رجال الشرطة في سيارته على كمية من الأسلحة و عدد كبير من القنابل اليدوية وبنادق كالاشنيكوف ومسدسات ومتفجرات. و أدخل فوسيليتش في جهاز "جي.بي.اس" خاص به عنوانا في باريس، وقد عثر على هذا العنوان مكتوبا على قصاصة ورق أيضا،
# 0  بدأت محكمة ميونخ النظر في اتهامات متعلقة برجل ...
# 1  أعلن حاكم كارولاينا الشمالية حالة الطورائ في م...
# 2  قالت وزارة الدفاع الأمريكية (البنتاغون) إن داع...
# 3  فشلت الولايات المتحدة وروسيا في الاتفاق على كي...
# 4  أثنى مدرب بايرن ميونيخ كارلو أنشيلوتي على مساع...
#
#                                        clean_article  \
# 0  بدات اليوم الجمعه ايلول سبتمبر في ميونيخ محاكم...
# 1  قال مسؤولون ان شخصا اصيب اصابه بالغه بعد تعرضه...
# 2  اعلن مسؤول في البنتاغون ان جنودا امريكيين في ش...
# 3  اجتمعت المجموعه الدوليه لدعم سوريا على هامش اج...
# 4  قال الايطالي كارلو انشيلوتي المدير الفني لفريق...
#
#                                        clean_summary
# 0  بدات محكمه ميونخ النظر في اتهامات متعلقه برجل ...
# 1  اعلن حاكم كارولاينا الشماليه حاله الطورائ في م...
# 2  قالت زاره الدفاع الامريكيه البنتاغون ان داعش ا...
# 3  فشلت الولايات المتحده روسيا في الاتفاق على كيف...
# 4  اثنى مدرب بايرن ميونيخ كارلو انشيلوتي على مساع...

# %% [markdown]
# **Cell 16 — Simple tokenization**

# %%
def simple_tokenize(text):
    return str(text).split()

df["article_tokens"] = df["clean_article"].apply(simple_tokenize)
df["summary_tokens"] = df["clean_summary"].apply(simple_tokenize)

# %% [markdown]
# **Cell 17 — Length statistics**

# %%
df["article_len"] = df["article_tokens"].apply(len)
df["summary_len"] = df["summary_tokens"].apply(len)

print("Article length stats:")
print(df["article_len"].describe())

print("\nSummary length stats:")
print(df["summary_len"].describe())
# Out:
# Article length stats:
# count    49581.000000
# mean       367.235877
# std        221.075358
# min         32.000000
# 25%        212.000000
# 50%        305.000000
# 75%        466.000000
# max       2827.000000
# Name: article_len, dtype: float64
#
# Summary length stats:
# count    49581.000000
# mean        33.266292
# std          3.705199
# min          2.000000
# 25%         31.000000
# 50%         34.000000
# 75%         36.000000
# max         44.000000
# Name: summary_len, dtype: float64

# %% [markdown]
# **Cell 18 — Plot token length distributions**

# %%
plt.figure(figsize=(10, 5))
plt.hist(df["article_len"], bins=50)
plt.title("Article Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 5))
plt.hist(df["summary_len"], bins=50)
plt.title("Summary Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Cell 19 — Filter empty or extremely short rows**

# %%
df = df[
    (df["clean_article"].str.strip() != "") &
    (df["clean_summary"].str.strip() != "") &
    (df["article_len"] >= 5) &
    (df["summary_len"] >= 3)
].copy()

print("Shape after filtering:", df.shape)
# Out:
# Shape after filtering: (49579, 8)

# %% [markdown]
# **Cell 20 — Save a cleaned version**

# %%
OUTPUT_DIR = Path("./dataset/processed_data")
OUTPUT_DIR.mkdir(exist_ok=True)

folder_name = selected_file.parent.name
file_name = selected_file.stem  
output_path = OUTPUT_DIR / f"cleaned_{folder_name}_{file_name}.csv"

df.to_csv(output_path, index=False, encoding="utf-8-sig")

print("Saved cleaned dataset to:", output_path.resolve())
# Out:
# Saved cleaned dataset to: C:\Users\moham\Desktop\NLP_Project\dataset\processed_data\cleaned_AraSum_AbsArSumCorpus_DW_article tab lead.csv

# %% [markdown]
# ## Load and process new file 5: `dataset\SumArabic\sumarabic-1.0-XXXXX.jsonl`

# %% [markdown]
# **Cell 7 — Load file by file**

# %%
from pathlib import Path

DATASET_DIR = Path("./dataset/raw_data/SumArabic/")

sumarabic_files = {
    "train": DATASET_DIR / "sumarabic-1.0-train.jsonl",
    "valid": DATASET_DIR / "sumarabic-1.0-valid.jsonl",
    "test":  DATASET_DIR / "sumarabic-1.0-test.jsonl",
    "ood":   DATASET_DIR / "sumarabic-1.0-ood.jsonl",
}

import json
import pandas as pd

def load_jsonl_file(path):
    rows = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            rows.append(json.loads(line))
    return pd.DataFrame(rows)

dfs = []

for split_name, file_path in sumarabic_files.items():
    
    print("Loading:", file_path)

    df = load_jsonl_file(file_path)

    # Add split identifier column
    df["split"] = split_name

    dfs.append(df)
# Out:
# Loading: dataset\raw_data\SumArabic\sumarabic-1.0-train.jsonl
# Loading: dataset\raw_data\SumArabic\sumarabic-1.0-valid.jsonl
# Loading: dataset\raw_data\SumArabic\sumarabic-1.0-test.jsonl
# Loading: dataset\raw_data\SumArabic\sumarabic-1.0-ood.jsonl

# %% [markdown]
# **Cell 8 — Inspect the dataset**

# %%
df = pd.concat(dfs, ignore_index=True)

print("Combined dataset shape:", df.shape)
display(df.head())
# Out:
# Combined dataset shape: (84764, 11)
#   dataset                                           filename  \
# 0   train  crawl-data/CC-MAIN-2019-04/segments/1547583705...
# 1   train  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 2   train  crawl-data/CC-MAIN-2019-04/segments/1547583662...
# 3   train  crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 4   train  crawl-data/CC-MAIN-2018-39/segments/1537267155...
#
#                                      headline  length     offset  \
# 0   المصري فؤاد الطاهر بطل للشطرنج الديناميكي   14478  750279704
# 1  حملة انتخابية محمومة قبل "الثلاثاء الكبير"   15030  770295734
# 2              55% من نزلاء «الأحداث» مواطنون   16581  789406684
# 3           مركز متخصص في الكلى بمستشفى خليفة   16661  754857257
# 4          تأهيل ضحايا حوادث المرور في أبوظبي   14583  712490285
#
#                published           section         subdomain  \
# 0  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 1  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 2  2008-02-04 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 3  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 4  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
#
#                                                 text  \
# 0  اختتمت مساء أول من أمس نهائيات بطولة الإمارات ...
# 1  مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب)...
# 2  أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتواف...
# 3  قال استشاري أمراض الكلى في مدينة الشيخ خليفة ا...
# 4  بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشا...
#
#                                                  url  split
# 0  https://www.emaratalyoum.com/local-section/200...  train
# 1  https://www.emaratalyoum.com/local-section/200...  train
# 2  https://www.emaratalyoum.com/local-section/200...  train
# 3  https://www.emaratalyoum.com/local-section/200...  train
# 4  https://www.emaratalyoum.com/local-section/200...  train

# %% [markdown]
# **Cell 9 — Check null values and duplicates**

# %%
if isinstance(df, pd.DataFrame):
    print("Null values per column:\n")
    print(df.isnull().sum())

    print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Null values per column:
#
# dataset      0
# filename     0
# headline     0
# length       0
# offset       0
# published    0
# section      0
# subdomain    0
# text         0
# url          0
# split        0
# dtype: int64
#
# Duplicate rows: 0

# %% [markdown]
# **Cell 10 — Identify the article and summary columns**

# %%
df = df.rename(columns={
    "text": "article",
    "headline": "summary"
})

df = df.dropna(subset=["article", "summary"])

ARTICLE_COL = "article"
SUMMARY_COL = "summary"
print("Article column:", ARTICLE_COL)
print("Summary column:", SUMMARY_COL)
# Out:
# Article column: article
# Summary column: summary

# %% [markdown]
# **Cell 11 — Keep only the important columns**

# %%
df = df.dropna(subset=[ARTICLE_COL, SUMMARY_COL]).drop_duplicates()

print("Cleaned shape:", df.shape)
display(df.head())
# Out:
# Cleaned shape: (84764, 11)
#   dataset                                           filename  \
# 0   train  crawl-data/CC-MAIN-2019-04/segments/1547583705...
# 1   train  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 2   train  crawl-data/CC-MAIN-2019-04/segments/1547583662...
# 3   train  crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 4   train  crawl-data/CC-MAIN-2018-39/segments/1537267155...
#
#                                       summary  length     offset  \
# 0   المصري فؤاد الطاهر بطل للشطرنج الديناميكي   14478  750279704
# 1  حملة انتخابية محمومة قبل "الثلاثاء الكبير"   15030  770295734
# 2              55% من نزلاء «الأحداث» مواطنون   16581  789406684
# 3           مركز متخصص في الكلى بمستشفى خليفة   16661  754857257
# 4          تأهيل ضحايا حوادث المرور في أبوظبي   14583  712490285
#
#                published           section         subdomain  \
# 0  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 1  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 2  2008-02-04 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 3  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 4  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
#
#                                              article  \
# 0  اختتمت مساء أول من أمس نهائيات بطولة الإمارات ...
# 1  مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب)...
# 2  أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتواف...
# 3  قال استشاري أمراض الكلى في مدينة الشيخ خليفة ا...
# 4  بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشا...
#
#                                                  url  split
# 0  https://www.emaratalyoum.com/local-section/200...  train
# 1  https://www.emaratalyoum.com/local-section/200...  train
# 2  https://www.emaratalyoum.com/local-section/200...  train
# 3  https://www.emaratalyoum.com/local-section/200...  train
# 4  https://www.emaratalyoum.com/local-section/200...  train

# %% [markdown]
# **Cell 12 — Print raw Arabic examples**

# %%
for i in range(min(5, len(df))):
    print("=" * 80)
    print(f"Example {i+1}")
    print("\nARTICLE:\n")
    print(df.iloc[i][ARTICLE_COL])
    print("\nSUMMARY:\n")
    print(df.iloc[i][SUMMARY_COL])
    print()
# Out:
# ================================================================================
# Example 1
#
# ARTICLE:
#
# اختتمت مساء أول من أمس نهائيات بطولة الإمارات للشطرنج الديناميكي المفتوحة التي نظمها اتحاد الإمارات للشطرنج بمقر نادي دبي للشطرنج والثقافة حيث توج الأستاذ الدولي المصري فؤاد الطاهر بطلا للمسابقة برصيد 6 نقاط من 7 جولات.
#
# SUMMARY:
#
# المصري فؤاد الطاهر بطل للشطرنج الديناميكي
#
# ================================================================================
# Example 2
#
# ARTICLE:
#
# مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب) - توقع المرشح الجمهوري جون
#
# SUMMARY:
#
# حملة انتخابية محمومة قبل "الثلاثاء الكبير"
#
# ================================================================================
# Example 3
#
# ARTICLE:
#
# أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتوافدون على مركز رعاية الأحداث سنوياً، 55% منهم مواطنون و45% مقيمون.
#
# SUMMARY:
#
# 55% من نزلاء «الأحداث» مواطنون
#
# ================================================================================
# Example 4
#
# ARTICLE:
#
# قال استشاري أمراض الكلى في مدينة الشيخ خليفة الطبية في أبوظبي الدكتور ياسين شحات، إن المدينة ستطلق قريباً مشروعات وأبحاثا لمعرفة معدلات انتشار أمراض الكلى في أبوظبي وأسباب الإصابة بها، إلى جانب وضع الخطط والاستراتيجيات الوقائية والعلاجية الواجب تنفيذها لمواجهة المرض».
#
# SUMMARY:
#
# مركز متخصص في الكلى بمستشفى خليفة
#
# ================================================================================
# Example 5
#
# ARTICLE:
#
# بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشاء مركز وطني شامل لتأهيل متضرري الحوادث المرورية، يختص بتقديم العلاج الطبيعي للمصابين، إلى جانب التأهيل الشامل بمداخلاته الطبية والنفسية والاجتماعية والمهنية والترفيهية، على غرار أرقى المراكز المماثلة في العالم.
#
# SUMMARY:
#
# تأهيل ضحايا حوادث المرور في أبوظبي

# %% [markdown]
# **Cell 13 — Arabic preprocessing functions**

# %%
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ      # Tatwil/Kashida
                         """, re.VERBOSE)

def remove_diacritics(text):
    text = str(text)
    return re.sub(arabic_diacritics, "", text)


def normalize_arabic(text):
    text = str(text)

    # Normalize different forms of Alef
    text = re.sub(r"[إأآا]", "ا", text)

    # text = re.sub(r"ى", "ي", text)
    # text = re.sub(r"ئ", "ي", text)
    # text = re.sub(r"ؤ", "و", text)
    text = re.sub(r"ة", "ه", text)
    text = re.sub(r"گ", "ك", text)

    return text


def clean_arabic_text(text):
    text = str(text)

    # Remove URLs
    text = re.sub(r"http\S+|www\S+|https\S+", " ", text)

    # Remove email addresses
    text = re.sub(r"\S+@\S+", " ", text)

    # Remove diacritics
    text = remove_diacritics(text)

    # Normalize Arabic letters
    text = normalize_arabic(text)

    # Separate concatenated و from Arabic words
    # Example: والاقتصاد -> و الاقتصاد
    text = re.sub(r"\bو(?=[\u0621-\u064A]{2,})", "و ", text)

    # Remove punctuation marks whether loose or concatenated
    punctuation_pattern = r"[!:\'’،؛\"/؟,.،؛()\[\]{}<>ـ\-–—]"
    text = re.sub(punctuation_pattern, " ", text)

    # Keep Arabic letters and spaces only
    text = re.sub(r"[^\u0600-\u06FF\s]", " ", text)

    # Remove single Arabic letters surrounded by spaces
    # Example: "ذهب ا الى" -> "ذهب الى"
    text = re.sub(r"(?<=\s)[\u0621-\u064A](?=\s)", " ", text)

    # Remove single Arabic letter at beginning or end
    text = re.sub(r"^[\u0621-\u064A]\s+", " ", text)
    text = re.sub(r"\s+[\u0621-\u064A]$", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# **Cell 14 — Test preprocessing on a few rows**

# %%
sample_df = df.head(5).copy()

sample_df["clean_article"] = sample_df[ARTICLE_COL].apply(clean_arabic_text)
sample_df["clean_summary"] = sample_df[SUMMARY_COL].apply(clean_arabic_text)

for i in range(len(sample_df)):
    print("=" * 100)
    print(f"Sample {i+1}")
    
    print("\nORIGINAL ARTICLE:\n")
    print(sample_df.iloc[i][ARTICLE_COL])
    
    print("\nCLEAN ARTICLE:\n")
    print(sample_df.iloc[i]["clean_article"])
    
    print("\nORIGINAL SUMMARY:\n")
    print(sample_df.iloc[i][SUMMARY_COL])
    
    print("\nCLEAN SUMMARY:\n")
    print(sample_df.iloc[i]["clean_summary"])
# Out:
# ====================================================================================================
# Sample 1
#
# ORIGINAL ARTICLE:
#
# اختتمت مساء أول من أمس نهائيات بطولة الإمارات للشطرنج الديناميكي المفتوحة التي نظمها اتحاد الإمارات للشطرنج بمقر نادي دبي للشطرنج والثقافة حيث توج الأستاذ الدولي المصري فؤاد الطاهر بطلا للمسابقة برصيد 6 نقاط من 7 جولات.
#
# CLEAN ARTICLE:
#
# اختتمت مساء اول من امس نهائيات بطوله الامارات للشطرنج الديناميكي المفتوحه التي نظمها اتحاد الامارات للشطرنج بمقر نادي دبي للشطرنج الثقافه حيث توج الاستاذ الدولي المصري فؤاد الطاهر بطلا للمسابقه برصيد نقاط من جولات
#
# ORIGINAL SUMMARY:
#
# المصري فؤاد الطاهر بطل للشطرنج الديناميكي
#
# CLEAN SUMMARY:
#
# المصري فؤاد الطاهر بطل للشطرنج الديناميكي
# ====================================================================================================
# Sample 2
#
# ORIGINAL ARTICLE:
#
# مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب) - توقع المرشح الجمهوري جون
#
# CLEAN ARTICLE:
#
# مينيابوليس الولايات المتحده توقع المرشح الجمهوري جون
#
# ORIGINAL SUMMARY:
#
# حملة انتخابية محمومة قبل "الثلاثاء الكبير"
#
# CLEAN SUMMARY:
#
# حمله انتخابيه محمومه قبل الثلاثاء الكبير
# ====================================================================================================
# Sample 3
#
# ORIGINAL ARTICLE:
#
# أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتوافدون على مركز رعاية الأحداث سنوياً، 55% منهم مواطنون و45% مقيمون.
#
# CLEAN ARTICLE:
#
# افاد مصدر في شرطه ابوظبي بان نحو طفل يتوافدون على مركز رعايه الاحداث سنويا منهم مواطنون مقيمون
#
# ORIGINAL SUMMARY:
#
# 55% من نزلاء «الأحداث» مواطنون
#
# CLEAN SUMMARY:
#
# من نزلاء الاحداث مواطنون
# ====================================================================================================
# Sample 4
#
# ORIGINAL ARTICLE:
#
# قال استشاري أمراض الكلى في مدينة الشيخ خليفة الطبية في أبوظبي الدكتور ياسين شحات، إن المدينة ستطلق قريباً مشروعات وأبحاثا لمعرفة معدلات انتشار أمراض الكلى في أبوظبي وأسباب الإصابة بها، إلى جانب وضع الخطط والاستراتيجيات الوقائية والعلاجية الواجب تنفيذها لمواجهة المرض».
#
# CLEAN ARTICLE:
#
# قال استشاري امراض الكلى في مدينه الشيخ خليفه الطبيه في ابوظبي الدكتور ياسين شحات ان المدينه ستطلق قريبا مشروعات ابحاثا لمعرفه معدلات انتشار امراض الكلى في ابوظبي اسباب الاصابه بها الى جانب ضع الخطط الاستراتيجيات الوقائيه العلاجيه الواجب تنفيذها لمواجهه المرض
#
# ORIGINAL SUMMARY:
#
# مركز متخصص في الكلى بمستشفى خليفة
#
# CLEAN SUMMARY:
#
# مركز متخصص في الكلى بمستشفى خليفه
# ====================================================================================================
# Sample 5
#
# ORIGINAL ARTICLE:
#
# بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشاء مركز وطني شامل لتأهيل متضرري الحوادث المرورية، يختص بتقديم العلاج الطبيعي للمصابين، إلى جانب التأهيل الشامل بمداخلاته الطبية والنفسية والاجتماعية والمهنية والترفيهية، على غرار أرقى المراكز المماثلة في العالم.
#
# CLEAN ARTICLE:
#
# بدات القياده العامه لشرطه ابوظبي التنسيق لانشاء مركز طني شامل لتاهيل متضرري الحوادث المروريه يختص بتقديم العلاج الطبيعي للمصابين الى جانب التاهيل الشامل بمداخلاته الطبيه النفسيه الاجتماعيه المهنيه الترفيهيه على غرار ارقى المراكز المماثله في العالم
#
# ORIGINAL SUMMARY:
#
# تأهيل ضحايا حوادث المرور في أبوظبي
#
# CLEAN SUMMARY:
#
# تاهيل ضحايا حوادث المرور في ابوظبي

# %% [markdown]
# **Cell 15 — Apply preprocessing to the full dataset**

# %%
df["clean_article"] = df[ARTICLE_COL].astype(str).apply(clean_arabic_text)
df["clean_summary"] = df[SUMMARY_COL].astype(str).apply(clean_arabic_text)

display(df.head())
# Out:
#   dataset                                           filename  \
# 0   train  crawl-data/CC-MAIN-2019-04/segments/1547583705...
# 1   train  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 2   train  crawl-data/CC-MAIN-2019-04/segments/1547583662...
# 3   train  crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 4   train  crawl-data/CC-MAIN-2018-39/segments/1537267155...
#
#                                       summary  length     offset  \
# 0   المصري فؤاد الطاهر بطل للشطرنج الديناميكي   14478  750279704
# 1  حملة انتخابية محمومة قبل "الثلاثاء الكبير"   15030  770295734
# 2              55% من نزلاء «الأحداث» مواطنون   16581  789406684
# 3           مركز متخصص في الكلى بمستشفى خليفة   16661  754857257
# 4          تأهيل ضحايا حوادث المرور في أبوظبي   14583  712490285
#
#                published           section         subdomain  \
# 0  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 1  2008-02-03 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 2  2008-02-04 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 3  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
# 4  2008-02-05 00:00+0400  emaratalyoum.com  emaratalyoum.com
#
#                                              article  \
# 0  اختتمت مساء أول من أمس نهائيات بطولة الإمارات ...
# 1  مينيابوليس (الولايات المتحدة) 3-2-2008 (ا ف ب)...
# 2  أفاد مصدر في شرطة أبوظبي بأن نحو 700 طفل يتواف...
# 3  قال استشاري أمراض الكلى في مدينة الشيخ خليفة ا...
# 4  بدأت القيادة العامة لشرطة أبوظبي التنسيق لإنشا...
#
#                                                  url  split  \
# 0  https://www.emaratalyoum.com/local-section/200...  train
# 1  https://www.emaratalyoum.com/local-section/200...  train
# 2  https://www.emaratalyoum.com/local-section/200...  train
# 3  https://www.emaratalyoum.com/local-section/200...  train
# 4  https://www.emaratalyoum.com/local-section/200...  train
#
#                                        clean_article  \
# 0  اختتمت مساء اول من امس نهائيات بطوله الامارات ...
# 1  مينيابوليس الولايات المتحده توقع المرشح الجمهو...
# 2  افاد مصدر في شرطه ابوظبي بان نحو طفل يتوافدون ...
# 3  قال استشاري امراض الكلى في مدينه الشيخ خليفه ا...
# 4  بدات القياده العامه لشرطه ابوظبي التنسيق لانشا...
#
#                                clean_summary
# 0  المصري فؤاد الطاهر بطل للشطرنج الديناميكي
# 1   حمله انتخابيه محمومه قبل الثلاثاء الكبير
# 2                   من نزلاء الاحداث مواطنون
# 3          مركز متخصص في الكلى بمستشفى خليفه
# 4         تاهيل ضحايا حوادث المرور في ابوظبي

# %% [markdown]
# **Cell 16 — Simple tokenization**

# %%
def simple_tokenize(text):
    return str(text).split()

df["article_tokens"] = df["clean_article"].apply(simple_tokenize)
df["summary_tokens"] = df["clean_summary"].apply(simple_tokenize)

# %% [markdown]
# **Cell 17 — Length statistics**

# %%
df["article_len"] = df["article_tokens"].apply(len)
df["summary_len"] = df["summary_tokens"].apply(len)

print("Article length stats:")
print(df["article_len"].describe())

print("\nSummary length stats:")
print(df["summary_len"].describe())
# Out:
# Article length stats:
# count    84764.000000
# mean        32.814001
# std         10.801534
# min          7.000000
# 25%         25.000000
# 50%         31.000000
# 75%         40.000000
# max         61.000000
# Name: article_len, dtype: float64
#
# Summary length stats:
# count    84764.000000
# mean         8.017979
# std          1.998851
# min          0.000000
# 25%          7.000000
# 50%          8.000000
# 75%          9.000000
# max         16.000000
# Name: summary_len, dtype: float64

# %% [markdown]
# **Cell 18 — Plot token length distributions**

# %%
plt.figure(figsize=(10, 5))
plt.hist(df["article_len"], bins=50)
plt.title("Article Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 5))
plt.hist(df["summary_len"], bins=50)
plt.title("Summary Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Cell 19 — Filter empty or extremely short rows**

# %%
df1 = df[
    (df["clean_article"].str.strip() != "") &
    (df["clean_summary"].str.strip() != "") &
    (df["article_len"] >= 5) &
    (df["summary_len"] >= 3)
].copy()

print("Shape after filtering:", df1.shape)
# Out:
# Shape after filtering: (84752, 17)

# %% [markdown]
# **Cell 20 — Save a cleaned version**

# %%
train_df = df[df["split"] == "train"]
valid_df = df[df["split"] == "valid"]
test_df  = df[df["split"] == "test"]
ood_df   = df[df["split"] == "ood"]

# %%
OUTPUT_DIR = Path("./dataset/processed_data")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

train_df.to_csv(OUTPUT_DIR/"SumArabic-train.csv", index=False, encoding="utf-8-sig")
valid_df.to_csv(OUTPUT_DIR/"SumArabic-valid.csv", index=False, encoding="utf-8-sig")
test_df.to_csv(OUTPUT_DIR/"SumArabic-test.csv", index=False, encoding="utf-8-sig")
ood_df.to_csv(OUTPUT_DIR/"SumArabic-ood.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Load and process new file 9: `dataset\Egyptian_Text_Summarisation\data\train-00000-of-00001.parquet`

# %% [markdown]
# **Cell 7 — Load file by file**

# %%
file_index = 9
selected_file = candidate_files[file_index]

print("Loading:", selected_file)

df = try_load_file(selected_file)

type(df)
# Out:
# Loading: dataset\raw_data\Egyptian_Text_Summarisation\data\train-00000-of-00001.parquet
# pandas.core.frame.DataFrame

# %% [markdown]
# **Cell 8 — Inspect the dataset**

# %%
if isinstance(df, pd.DataFrame):
    print("Shape:", df.shape)
    display(df.head())
    print("\nColumns:")
    print(df.columns.tolist())
else:
    print("Loaded object is not a DataFrame.")
    print(df)
# Out:
# Shape: (3689, 3)
#                                                 text  \
# 0  كتير من الشباب دلوقتي بيفكروا ألف مرة قبل ما ي...
# 1  الظروف الاقتصادية الصعبة خلت كتير من الشباب يأ...
# 2  موجات التضخم المتتالية أثرت بشكل مباشر على قدر...
# 3  الأسر المصرية بقت بتميل أكتر لإنها تركز على جو...
# 4  في ظل التحديات الاقتصادية اللي بتواجه الأسر، ب...
#
#                                      summarized_text  \
# 0  غلاء المعيشة بيخلي الشباب يقللوا عدد الأطفال ب...
# 1  الوضع الاقتصادي المتردي بيأجل قرارات الجواز وا...
# 2  التضخم بيخلي الأسر تعيد حساباتها في قرارات الإ...
# 3  الأعباء الاقتصادية بتخلي الأسر تركز على جودة ح...
# 4  الحكومات ممكن تحتاج تقدم دعم وحوافز للأسر عشان...
#
#                                  source_topics
# 0  تأثير الأعباء الاقتصادية على قرارات الإنجاب
# 1  تأثير الأعباء الاقتصادية على قرارات الإنجاب
# 2  تأثير الأعباء الاقتصادية على قرارات الإنجاب
# 3  تأثير الأعباء الاقتصادية على قرارات الإنجاب
# 4  تأثير الأعباء الاقتصادية على قرارات الإنجاب
# Columns:
# ['text', 'summarized_text', 'source_topics']

# %% [markdown]
# **Cell 9 — Check null values and duplicates**

# %%
if isinstance(df, pd.DataFrame):
    print("Null values per column:\n")
    print(df.isnull().sum())
    print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Null values per column:
#
# text               0
# summarized_text    0
# source_topics      0
# dtype: int64
#
# Duplicate rows: 0

# %% [markdown]
# **Cell 10 — Identify the article and summary columns**

# %%
ARTICLE_COL = "text"  
SUMMARY_COL = "summarized_text"  

print("Article column:", ARTICLE_COL)
print("Summary column:", SUMMARY_COL)
# Out:
# Article column: text
# Summary column: summarized_text

# %% [markdown]
# **Cell 11 — Keep only the important columns**

# %%
df = df[[ARTICLE_COL, SUMMARY_COL]].copy()
df = df.dropna(subset=[ARTICLE_COL, SUMMARY_COL]).drop_duplicates()

print("Cleaned shape:", df.shape)
display(df.head())
# Out:
# Cleaned shape: (3689, 2)
#                                                 text  \
# 0  كتير من الشباب دلوقتي بيفكروا ألف مرة قبل ما ي...
# 1  الظروف الاقتصادية الصعبة خلت كتير من الشباب يأ...
# 2  موجات التضخم المتتالية أثرت بشكل مباشر على قدر...
# 3  الأسر المصرية بقت بتميل أكتر لإنها تركز على جو...
# 4  في ظل التحديات الاقتصادية اللي بتواجه الأسر، ب...
#
#                                      summarized_text
# 0  غلاء المعيشة بيخلي الشباب يقللوا عدد الأطفال ب...
# 1  الوضع الاقتصادي المتردي بيأجل قرارات الجواز وا...
# 2  التضخم بيخلي الأسر تعيد حساباتها في قرارات الإ...
# 3  الأعباء الاقتصادية بتخلي الأسر تركز على جودة ح...
# 4  الحكومات ممكن تحتاج تقدم دعم وحوافز للأسر عشان...

# %% [markdown]
# **Cell 12 — Print raw Arabic examples**

# %%
for i in range(min(5, len(df))):
    print("=" * 80)
    print(f"Example {i+1}")
    print("\nARTICLE:\n")
    print(df.iloc[i][ARTICLE_COL])
    print("\nSUMMARY:\n")
    print(df.iloc[i][SUMMARY_COL])
    print()
# Out:
# ================================================================================
# Example 1
#
# ARTICLE:
#
# كتير من الشباب دلوقتي بيفكروا ألف مرة قبل ما ياخدوا قرار الإنجاب، خصوصًا مع غلاء الأسعار اللي بنشوفه كل يوم. تكاليف تربية طفل واحد بس بقت مرهقة جدًا، من مصاريف الأكل والشرب واللبس، لحد التعليم والصحة. كل ده بيخلي الأسر تفكر تقلل عدد الأطفال عشان تقدر توفر حياة كريمة للي موجودين.
#
# SUMMARY:
#
# غلاء المعيشة بيخلي الشباب يقللوا عدد الأطفال بسبب صعوبة توفير احتياجاتهم الأساسية وتكاليف التربية المرتفعة.
#
# ================================================================================
# Example 2
#
# ARTICLE:
#
# الظروف الاقتصادية الصعبة خلت كتير من الشباب يأجلوا خطوة الجواز والإنجاب، عشان مش عايزين يجيبوا أطفال في ظل وضع مادي غير مستقر. الأولية بقت لتأمين المستقبل المادي قبل تكوين أسرة.
#
# SUMMARY:
#
# الوضع الاقتصادي المتردي بيأجل قرارات الجواز والإنجاب عند الشباب لتأمين مستقبلهم المادي.
#
# ================================================================================
# Example 3
#
# ARTICLE:
#
# موجات التضخم المتتالية أثرت بشكل مباشر على قدرة الأسر على التخطيط للمستقبل، وده بيشمل طبعًا قرار الإنجاب. لما أسعار السلع الأساسية بتزيد بشكل جنوني، الأسر بتضطر تعيد حساباتها وتبص على الأولويات، وممكن ده يخليهم يفكروا مرتين قبل ما يضيفوا فرد جديد للأسرة، عشان يقدروا يكفوا احتياجاتهم الأساسية.
#
# SUMMARY:
#
# التضخم بيخلي الأسر تعيد حساباتها في قرارات الإنجاب عشان تقدر توفر احتياجاتها الأساسية في ظل ارتفاع الأسعار.
#
# ================================================================================
# Example 4
#
# ARTICLE:
#
# الأسر المصرية بقت بتميل أكتر لإنها تركز على جودة الحياة للطفل الواحد أو الطفلين اللي عندها، بدل ما تجيب عدد كبير من الأطفال وتتعب في توفير أساسيات الحياة ليهم كلهم. ده عشان الأعباء الاقتصادية خلت توفير مستوى معيشة كويس لعدد قليل من الأطفال أسهل من توفيره لعدد كبير.
#
# SUMMARY:
#
# الأعباء الاقتصادية بتخلي الأسر تركز على جودة حياة عدد قليل من الأطفال بدل زيادة عددهم.
#
# ================================================================================
# Example 5
#
# ARTICLE:
#
# في ظل التحديات الاقتصادية اللي بتواجه الأسر، بقت الحكومات محتاجة تفكر في برامج دعم أو حوافز عشان تشجع على الإنجاب، خصوصًا لو في قلق من انخفاض معدلات المواليد. الدعم ده ممكن يكون في صورة تسهيلات تعليمية، رعاية صحية مجانية للأطفال، أو حتى دعم مادي مباشر للأسر الجديدة عشان تخفف عنهم الأعباء المالية اللي بتصاحب قرار الإنجاب.
#
# SUMMARY:
#
# الحكومات ممكن تحتاج تقدم دعم وحوافز للأسر عشان تشجع على الإنجاب في ظل الأعباء الاقتصادية وتجنب انخفاض المواليد.

# %% [markdown]
# **Cell 13 — Arabic preprocessing functions**

# %%
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ      # Tatwil/Kashida
                         """, re.VERBOSE)

def remove_diacritics(text):
    text = str(text)
    return re.sub(arabic_diacritics, "", text)


def normalize_arabic(text):
    text = str(text)

    # Normalize different forms of Alef
    text = re.sub(r"[إأآا]", "ا", text)
    # text = re.sub(r"ى", "ي", text)
    # text = re.sub(r"ئ", "ي", text)
    text = re.sub(r"ؤ", "و", text)
    text = re.sub(r"ة", "ه", text)
    text = re.sub(r"گ", "ك", text)

    return text


def clean_arabic_text(text):
    text = str(text)

    # Remove URLs
    text = re.sub(r"http\S+|www\S+|https\S+", " ", text)

    # Remove email addresses
    text = re.sub(r"\S+@\S+", " ", text)

    # Remove diacritics
    text = remove_diacritics(text)

    # Normalize Arabic letters
    text = normalize_arabic(text)

    # Separate concatenated و from Arabic words
    # Example: والاقتصاد -> و الاقتصاد
    text = re.sub(r"\bو(?=[\u0621-\u064A]{2,})", "و ", text)

    # Remove punctuation marks whether loose or concatenated
    punctuation_pattern = r"[!:\'’،؛\"/؟,.،؛()\[\]{}<>ـ\-–—]"
    text = re.sub(punctuation_pattern, " ", text)

    # Keep Arabic letters and spaces only
    text = re.sub(r"[^\u0600-\u06FF\s]", " ", text)

    # Remove single Arabic letters surrounded by spaces
    # Example: "ذهب ا الى" -> "ذهب الى"
    text = re.sub(r"(?<=\s)[\u0621-\u064A](?=\s)", " ", text)

    # Remove single Arabic letter at beginning or end
    text = re.sub(r"^[\u0621-\u064A]\s+", " ", text)
    text = re.sub(r"\s+[\u0621-\u064A]$", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# **Cell 14 — Test preprocessing on a few rows**

# %%
sample_df = df.head(5).copy()

sample_df["clean_article"] = sample_df[ARTICLE_COL].apply(clean_arabic_text)
sample_df["clean_summary"] = sample_df[SUMMARY_COL].apply(clean_arabic_text)

for i in range(len(sample_df)):
    print("=" * 100)
    print(f"Sample {i+1}")
    
    print("\nORIGINAL ARTICLE:\n")
    print(sample_df.iloc[i][ARTICLE_COL])
    
    print("\nCLEAN ARTICLE:\n")
    print(sample_df.iloc[i]["clean_article"])
    
    print("\nORIGINAL SUMMARY:\n")
    print(sample_df.iloc[i][SUMMARY_COL])
    
    print("\nCLEAN SUMMARY:\n")
    print(sample_df.iloc[i]["clean_summary"])
# Out:
# ====================================================================================================
# Sample 1
#
# ORIGINAL ARTICLE:
#
# كتير من الشباب دلوقتي بيفكروا ألف مرة قبل ما ياخدوا قرار الإنجاب، خصوصًا مع غلاء الأسعار اللي بنشوفه كل يوم. تكاليف تربية طفل واحد بس بقت مرهقة جدًا، من مصاريف الأكل والشرب واللبس، لحد التعليم والصحة. كل ده بيخلي الأسر تفكر تقلل عدد الأطفال عشان تقدر توفر حياة كريمة للي موجودين.
#
# CLEAN ARTICLE:
#
# كتير من الشباب دلوقتي بيفكروا الف مره قبل ما ياخدوا قرار الانجاب خصوصا مع غلاء الاسعار اللي بنشوفه كل يوم تكاليف تربيه طفل احد بس بقت مرهقه جدا من مصاريف الاكل الشرب اللبس لحد التعليم الصحه كل ده بيخلي الاسر تفكر تقلل عدد الاطفال عشان تقدر توفر حياه كريمه للي موجودين
#
# ORIGINAL SUMMARY:
#
# غلاء المعيشة بيخلي الشباب يقللوا عدد الأطفال بسبب صعوبة توفير احتياجاتهم الأساسية وتكاليف التربية المرتفعة.
#
# CLEAN SUMMARY:
#
# غلاء المعيشه بيخلي الشباب يقللوا عدد الاطفال بسبب صعوبه توفير احتياجاتهم الاساسيه تكاليف التربيه المرتفعه
# ====================================================================================================
# Sample 2
#
# ORIGINAL ARTICLE:
#
# الظروف الاقتصادية الصعبة خلت كتير من الشباب يأجلوا خطوة الجواز والإنجاب، عشان مش عايزين يجيبوا أطفال في ظل وضع مادي غير مستقر. الأولية بقت لتأمين المستقبل المادي قبل تكوين أسرة.
#
# CLEAN ARTICLE:
#
# الظروف الاقتصاديه الصعبه خلت كتير من الشباب ياجلوا خطوه الجواز الانجاب عشان مش عايزين يجيبوا اطفال في ظل ضع مادي غير مستقر الاوليه بقت لتامين المستقبل المادي قبل تكوين اسره
#
# ORIGINAL SUMMARY:
#
# الوضع الاقتصادي المتردي بيأجل قرارات الجواز والإنجاب عند الشباب لتأمين مستقبلهم المادي.
#
# CLEAN SUMMARY:
#
# الوضع الاقتصادي المتردي بياجل قرارات الجواز الانجاب عند الشباب لتامين مستقبلهم المادي
# ====================================================================================================
# Sample 3
#
# ORIGINAL ARTICLE:
#
# موجات التضخم المتتالية أثرت بشكل مباشر على قدرة الأسر على التخطيط للمستقبل، وده بيشمل طبعًا قرار الإنجاب. لما أسعار السلع الأساسية بتزيد بشكل جنوني، الأسر بتضطر تعيد حساباتها وتبص على الأولويات، وممكن ده يخليهم يفكروا مرتين قبل ما يضيفوا فرد جديد للأسرة، عشان يقدروا يكفوا احتياجاتهم الأساسية.
#
# CLEAN ARTICLE:
#
# موجات التضخم المتتاليه اثرت بشكل مباشر على قدره الاسر على التخطيط للمستقبل ده بيشمل طبعا قرار الانجاب لما اسعار السلع الاساسيه بتزيد بشكل جنوني الاسر بتضطر تعيد حساباتها تبص على الاولويات ممكن ده يخليهم يفكروا مرتين قبل ما يضيفوا فرد جديد للاسره عشان يقدروا يكفوا احتياجاتهم الاساسيه
#
# ORIGINAL SUMMARY:
#
# التضخم بيخلي الأسر تعيد حساباتها في قرارات الإنجاب عشان تقدر توفر احتياجاتها الأساسية في ظل ارتفاع الأسعار.
#
# CLEAN SUMMARY:
#
# التضخم بيخلي الاسر تعيد حساباتها في قرارات الانجاب عشان تقدر توفر احتياجاتها الاساسيه في ظل ارتفاع الاسعار
# ====================================================================================================
# Sample 4
#
# ORIGINAL ARTICLE:
#
# الأسر المصرية بقت بتميل أكتر لإنها تركز على جودة الحياة للطفل الواحد أو الطفلين اللي عندها، بدل ما تجيب عدد كبير من الأطفال وتتعب في توفير أساسيات الحياة ليهم كلهم. ده عشان الأعباء الاقتصادية خلت توفير مستوى معيشة كويس لعدد قليل من الأطفال أسهل من توفيره لعدد كبير.
#
# CLEAN ARTICLE:
#
# الاسر المصريه بقت بتميل اكتر لانها تركز على جوده الحياه للطفل الواحد او الطفلين اللي عندها بدل ما تجيب عدد كبير من الاطفال تتعب في توفير اساسيات الحياه ليهم كلهم ده عشان الاعباء الاقتصاديه خلت توفير مستوى معيشه كويس لعدد قليل من الاطفال اسهل من توفيره لعدد كبير
#
# ORIGINAL SUMMARY:
#
# الأعباء الاقتصادية بتخلي الأسر تركز على جودة حياة عدد قليل من الأطفال بدل زيادة عددهم.
#
# CLEAN SUMMARY:
#
# الاعباء الاقتصاديه بتخلي الاسر تركز على جوده حياه عدد قليل من الاطفال بدل زياده عددهم
# ====================================================================================================
# Sample 5
#
# ORIGINAL ARTICLE:
#
# في ظل التحديات الاقتصادية اللي بتواجه الأسر، بقت الحكومات محتاجة تفكر في برامج دعم أو حوافز عشان تشجع على الإنجاب، خصوصًا لو في قلق من انخفاض معدلات المواليد. الدعم ده ممكن يكون في صورة تسهيلات تعليمية، رعاية صحية مجانية للأطفال، أو حتى دعم مادي مباشر للأسر الجديدة عشان تخفف عنهم الأعباء المالية اللي بتصاحب قرار الإنجاب.
#
# CLEAN ARTICLE:
#
# في ظل التحديات الاقتصاديه اللي بتواجه الاسر بقت الحكومات محتاجه تفكر في برامج دعم او حوافز عشان تشجع على الانجاب خصوصا لو في قلق من انخفاض معدلات المواليد الدعم ده ممكن يكون في صوره تسهيلات تعليميه رعايه صحيه مجانيه للاطفال او حتى دعم مادي مباشر للاسر الجديده عشان تخفف عنهم الاعباء الماليه اللي بتصاحب قرار الانجاب
#
# ORIGINAL SUMMARY:
#
# الحكومات ممكن تحتاج تقدم دعم وحوافز للأسر عشان تشجع على الإنجاب في ظل الأعباء الاقتصادية وتجنب انخفاض المواليد.
#
# CLEAN SUMMARY:
#
# الحكومات ممكن تحتاج تقدم دعم حوافز للاسر عشان تشجع على الانجاب في ظل الاعباء الاقتصاديه تجنب انخفاض المواليد

# %% [markdown]
# **Cell 15 — Apply preprocessing to the full dataset**

# %%
df["clean_article"] = df[ARTICLE_COL].astype(str).apply(clean_arabic_text)
df["clean_summary"] = df[SUMMARY_COL].astype(str).apply(clean_arabic_text)

display(df.head())
# Out:
#                                                 text  \
# 0  كتير من الشباب دلوقتي بيفكروا ألف مرة قبل ما ي...
# 1  الظروف الاقتصادية الصعبة خلت كتير من الشباب يأ...
# 2  موجات التضخم المتتالية أثرت بشكل مباشر على قدر...
# 3  الأسر المصرية بقت بتميل أكتر لإنها تركز على جو...
# 4  في ظل التحديات الاقتصادية اللي بتواجه الأسر، ب...
#
#                                      summarized_text  \
# 0  غلاء المعيشة بيخلي الشباب يقللوا عدد الأطفال ب...
# 1  الوضع الاقتصادي المتردي بيأجل قرارات الجواز وا...
# 2  التضخم بيخلي الأسر تعيد حساباتها في قرارات الإ...
# 3  الأعباء الاقتصادية بتخلي الأسر تركز على جودة ح...
# 4  الحكومات ممكن تحتاج تقدم دعم وحوافز للأسر عشان...
#
#                                        clean_article  \
# 0  كتير من الشباب دلوقتي بيفكروا الف مره قبل ما ي...
# 1  الظروف الاقتصاديه الصعبه خلت كتير من الشباب يا...
# 2  موجات التضخم المتتاليه اثرت بشكل مباشر على قدر...
# 3  الاسر المصريه بقت بتميل اكتر لانها تركز على جو...
# 4  في ظل التحديات الاقتصاديه اللي بتواجه الاسر بق...
#
#                                        clean_summary
# 0  غلاء المعيشه بيخلي الشباب يقللوا عدد الاطفال ب...
# 1  الوضع الاقتصادي المتردي بياجل قرارات الجواز ال...
# 2  التضخم بيخلي الاسر تعيد حساباتها في قرارات الا...
# 3  الاعباء الاقتصاديه بتخلي الاسر تركز على جوده ح...
# 4  الحكومات ممكن تحتاج تقدم دعم حوافز للاسر عشان ...

# %% [markdown]
# **Cell 16 — Simple tokenization**

# %%
def simple_tokenize(text):
    return str(text).split()

df["article_tokens"] = df["clean_article"].apply(simple_tokenize)
df["summary_tokens"] = df["clean_summary"].apply(simple_tokenize)

# %% [markdown]
# **Cell 17 — Length statistics**

# %%
df["article_len"] = df["article_tokens"].apply(len)
df["summary_len"] = df["summary_tokens"].apply(len)

print("Article length stats:")
print(df["article_len"].describe())

print("\nSummary length stats:")
print(df["summary_len"].describe())
# Out:
# Article length stats:
# count    3689.000000
# mean       48.040390
# std        10.702709
# min        20.000000
# 25%        40.000000
# 50%        47.000000
# 75%        55.000000
# max        98.000000
# Name: article_len, dtype: float64
#
# Summary length stats:
# count    3689.00000
# mean       17.95473
# std         4.08211
# min         6.00000
# 25%        15.00000
# 50%        18.00000
# 75%        20.00000
# max        37.00000
# Name: summary_len, dtype: float64

# %% [markdown]
# **Cell 18 — Plot token length distributions**

# %%
plt.figure(figsize=(10, 5))
plt.hist(df["article_len"], bins=50)
plt.title("Article Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 5))
plt.hist(df["summary_len"], bins=50)
plt.title("Summary Token Length Distribution")
plt.xlabel("Number of tokens")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Cell 19 — Filter empty or extremely short rows**

# %%
df = df[
    (df["clean_article"].str.strip() != "") &
    (df["clean_summary"].str.strip() != "") &
    (df["article_len"] >= 5) &
    (df["summary_len"] >= 3)
].copy()

print("Shape after filtering:", df.shape)
# Out:
# Shape after filtering: (3689, 8)

# %% [markdown]
# **Cell 20 — Save a cleaned version**

# %%
OUTPUT_DIR = Path("./dataset/processed_data")
OUTPUT_DIR.mkdir(exist_ok=True)

folder_name = selected_file.parent.name
file_name = selected_file.stem  
output_path = OUTPUT_DIR / f"cleaned_Egyptian_Text_Summarisation_{folder_name}_{file_name}.csv"

df.to_csv(output_path, index=False, encoding="utf-8-sig")

print("Saved cleaned dataset to:", output_path.resolve())
# Out:
# Saved cleaned dataset to: C:\Users\moham\Desktop\NLP_Project\dataset\processed_data\cleaned_Egyptian_Text_Summarisation_data_train-00000-of-00001.csv
